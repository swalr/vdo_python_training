# %% [markdown]
# # Pandas (+ NumPy)

# %% [markdown]
# <b>Wat is het verschil tussen Pandas en NumPy?</b>

# %% [markdown]
# NumPy en pandas zijn python libraries die veel door data scientists worden gebruikt. Beide kunnen worden gebruikt om met grote databestanden te werken. <br> <br> Wij gaan vandaag meer focussen op functies in pandas, met name omdat numpy beter werkt met alleen numerieke data. Echter, wanneer je met data van de overheid werkt heb je vaker te maken met data van verschillende types (bijvoorbeeld tekst en numeriek â€“ denk aan databestanden met soort beroep en inkomen). Daarom wordt pandas het vaakst gebruikt voor data analyse. <br> <br>
# Pandas is op de library Numpy gebouwd, dus het is geen harde scheiding tussen de twee.

# %% [markdown]
# <b>Importeer pandas als pd en numpy als np. </b>

# %% [markdown]
# ## Datastructuren in pandas

# %% [markdown]
# <b>Wat zijn de 2 datastructuren in pandas? </b>

# %% [markdown]
# De twee hoofd datastructuren in pandas zijn Series en DataFrames. Een Series is een Ã©Ã©ndimensionale reeks met waarden. Een DataFrame is een tweedimensionale datastructuur met rijen en kolommen. Het is vergelijkbaar met een Excel-sheet. <br> <br> Vandaag gaan we focussen op DataFrames, omdat je het vaakst een csv bestand hebt die je wilt omzetten naar een Dataframe om analyses te kunnen uitvoeren. Je zult niet vaak een csv bestand hebben met maar een kolom (in pandas: een Series). <br> <br> Elke rij in een DataFrame (of in een Series) krijgt automatisch een nummer (hetzelfde als dat je in Excel rij-nummers ziet). Dit noemen we de Index.

# %% [markdown]
# ### Dataframe maken

# %% [markdown]
# Het eerste wat we gaan doen is een pandas DataFrame maken, zodat we daarna een aantal functies kunnen oefenen. Een DataFrame kun je zien als een tabel met rijen en kolommen waarin de data weergegeven wordt. Het makkelijkste voor vandaag is om een DataFrame vanaf een dictionary te maken. <br> <br> Later in de training zullen we ook een DataFrame maken door een csv-bestand in te lezen.

# %% [markdown]
# #### Van Dictionary tot DataFrame

# %% [markdown]
# <b>Wat zijn de kenmerken van een python dictionary? </b>

# %% [markdown]
# Reminder: een python dictionary is een datatype waarin je meerdere datapunten op kunt slaan met key-value paren.
# Een dictionary is op de volgende manier gekenmerkt:
# -	De data (key-value paren) bevindt zich tussen accolades {}
# -	Afzonderlijke key-value paren worden gescheiden met een komma (,)
# -	Tussen de key en value staat een dubbele punt (:)
# -	Keys moeten uniek zijn en kunnen niet gewijzigd worden

# %% [markdown]
# <b>Wat gebeurt er als je de code hieronder runt?</b>

# %% [markdown]
# <b>Waardoor komt deze foutmelding? Kan je de code fixen?</b>

# %% [markdown]
# <b>Gebruik de DataFrame() functie om van de dictionary data de dataframe df te maken. Print daarna df.</b>

# %% [markdown]
# Jupyter heeft een mooie layout voor dataframes, je hoeft de print functie dus niet te gebruiken.

# %% [markdown]
# <b>Nu willen we graag de index vervangen met de namen van de personen waarvan de data is: Peter, Shira, Leonie, Gael, Ali, Zelal, Max en Miro. </b>

# %% [markdown]
# <b>Zoek eerst even zelf op hoe dit moet, en probeer het daarna toe te passen.Tip: Google is je vriend!</b>

# %% [markdown]
# Let op: door df = te doen hebben we eigenlijk permanent de dataframe df veranderd. Dit is niet altijd wenselijk, omdat je soms terug wilt kunnen gaan naar de oorspronkelijke dataframe. In dat geval maak je een nieuwe variabel, bijvoorbeld df2, en daarna voer je de veranderingen uit.

# %% [markdown]
# <b>Er zijn een aantal fouten/rare dingen in de data. Kan jij ze spotten?</b>

# %% [markdown]
# Je gaat eerst leren hoe je met pandas met ontbrekende gegevens kunt omgaan. Hiervoor kun je een paar functies gebruiken. Het is eerst nuttig om te weten of een cel een lege waarde heeft. Dit gaan we doen door een functie te gebruiken die een boolean (True/False) teruggeeft afhankelijk van de waarde van een cel.

# %% [markdown]
# <b> Gebruik de functie isnull() om te checken of er lege cellen in df zijn.</b>

# %% [markdown]
# Hier zie je dus dat een aantal cellen inderdaad leeg zijn. Deze functie kan je ook toepassen op specifieke kolommen. Laten we kijken of er in de kolom Type auto lege cellen zijn.

# %% [markdown]
# <b> Zoek op hoe je deze functie op een specifieke kolom kan toepassen. Maak een nieuwe variabel lege_cellen_kolom aan die weergeeft of de kolom "Type auto" lege cellen heeft.</b>

# %% [markdown]
# De vierkante haakjes gebruik je heel vaak in pandas. Ze worden gebruikt om kolommen te selecteren. Let op: als je Ã©Ã©n haakje gebruikt dan is de output een Series. Als je twee haakjes gebruikt, dan is de output een DataFrame.

# %% [markdown]
# <b> Print de output als dataframe in plaats van een Series. Noem hem df_lefe_cellen_kolom.</b>

# %% [markdown]
# <b>Wat is het verschil tussen df.isnull() en pd.isnull(df)? Probeer het eens.</b>

# %% [markdown]
# Beide manieren om te schrijven kloppen. Zo zie je hoe er nooit maar Ã©Ã©n oplossing is in python.

# %% [markdown]
# Nu weten we hoe we voor een hele dataframe checken welke cellen leeg zijn, en hoe je het voor een kolom doet. Maar eigenlijk is het ook handig om alleen maar de rijen waarin er bij Type auto lege cellen zijn te printen.

# %% [markdown]
# <b> Hoe selecteer je de rijen waarin er bij Type auto lege cellen zijn?</b>

# %% [markdown]
# <b> Wat doet deze functie precies?</b>

# %% [markdown]
# <b>De functie checkt per rij of er cellen zijn waarin isnull() = True. Logischerwijze kun je dus ook rijen selecteren waarin isnull() = False is. Hoe zou je dit doen?</b>

# %% [markdown]
# Hier heb je conditioneel iets geselecteert. Meer hierover later.

# %% [markdown]
# Een variabel toevoegen maakt de code wat netter, overzichtelijker, en meer flexibel.

# %% [markdown]
# <b> Maak de variabel lege_cellen_rij aan die de rijen selecteert waarin Type auto leeg is.</b>

# %% [markdown]
# <b>Uiteraard kun je ook alle rijen printen waarin er lege cellen zijn (en dus niet alleen bij Type auto). Hoe zou je dit doen? Noem de nieuwe variabel lege_cellen_rijen. </b>

# %% [markdown]
# .any betekent dat de functie kijkt naar alle rijen/kolommen waarin er minstens Ã©Ã©n lege cel is. Door axis = 1 toe te voegen specificeer je dat het om de rijen gaat.

# %% [markdown]
# De vraag is nu: wat doe je met die lege cellen? Een optie is om een waarde aan de cellen te geven. Soms weet je wat die waarde is, maar vaak ook niet. Omdat we hier niet kunnen weten wat de waarde hoort te zijn gaan we de cellen vullen met de waarde 'onbekend'.

# %% [markdown]
# Let op: vanaf het moment dat je een dataframe gaat aanpassen (bijvoorbeeld door waarden te vervangen of te verwijderen) is het verstandig om met een kopie van de dataframe te werken. Dit omdat je anders jouw dataframe permanent verandert.

# %% [markdown]
# <b> Zoek de functie replace() op. Maak een nieuwe variabel df_replace waarin je alle lege cellen in de dataframe vervang met "onbekend"</b>

# %% [markdown]
# <b>de replace() functie is een methode om dit te doen. Je kunt ook fillna() gebruiken. Maak een nieuwe variabel df_fill en doe hetzelfde als hierboven met de fillna() functie.</b>

# %% [markdown]
# <b>Zoals net kun je ook deze functie op een bepaalde kolom toepassen, bijvoorbeeld Type Auto. Maak een nieuwe variabel df_filled_auto. Df_filled_auto is een dataframe waarin alleen de lege cellen in de kolom "Type auto" gevuld zijn met "onbekend.</b>

# %% [markdown]
# Hier zie je dat alleen de lege cellen in kolom Type auto vervangen zijn.

# %% [markdown]
# <b>Je kunt ook de functie toepassen op meerdere kolommen tegelijkertijd, bijvoorbeeld op Geslacht en Type auto. Hoe denk je dat het moet? Zet de nieuwe dataframe in de variabel df_filled_auto_geslacht.</b>

# %% [markdown]
# <!-- Nu weet je hoe je rijen met lege cellen kan identificeren. De vraag nu is: wat doe je met die lege cellen -->

# %% [markdown]
# Voor je data analyses helpt het echter niet per se om cellen met "unknown" te hebben. Vaak zul je rijen met lege cellen verwijderen. Het verwijderen van 100 rijen in een bestand van 20'000 heeft namelijk niet zo'n grote impact.

# %% [markdown]
# <b>De functie die je hiervoor gebruikt is .dropna. Deze werkt op dezelfde manier als in de vorige oefeningen. Kan jij:
# -  alle rijen waarin lege cellen zijn verwijderen. De nieuwe dataframe zet je in de variabel df_dropped.
# -  alle rijen waarin de kolom Type auto een lege cel heeft verwijderen (tip:hiervoor moet je op zoek naar een passende functie!). De nieuwe dataframe zet je in de variabel df_dropped_kolom.
# -  alle rijen waarin de kolomen Type auto en Geslacht een lege cel heeft verwijderen. De nieuwe dataframe zet je in de variabel df_dropped_kolommen.</b>

# %% [markdown]
# Dit is een oplossing voor opdracht 1.

# %% [markdown]
# Dit is een oplossing voor opdracht 2.

# %% [markdown]
# Dit is een oplossing voor opdracht 3.

# %% [markdown]
# <b>Je kunt ook beslissen om alle rijen waarin minimaal Ã©Ã©n lege cel is te verwijderen. Hiervoor gebruik je nog steeds .dropna, maar je moet een extra argument toevoegen. Google eens de .dropna functie; wat zijn de mogelijke argumenten hiervoor?</b>

# %% [markdown]
# <b>Hoe zou je denk je alle rijen waarin er minimaal Ã©Ã©n lege cel is verwijderen? Maak een nieuwe variabel df_zonder_lege_cellen </b>

# %% [markdown]
# In deze oefeningen heb je geleerd:
# -  hoe je een pandas DataFrame maakt vanaf een dictionary
# -  hoe je de index veranderd naar andere waarden
# -  hoe je lege cellen kan detecteren, vervangen, en hoe je specifieke of alle rijen met lege cellen kan verwijderen
