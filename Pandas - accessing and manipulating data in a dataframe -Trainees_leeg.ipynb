# %% [markdown]
# # Accessing and manipulating data in a pandas DataFrame

# %% [markdown]
# <b> Selecteer de kolom "Leeftijd" en zet hem in de variabel leeftijd. Zorg ervoor dat de output een Series is.</b>

# %% [markdown]
# <b> Doe nu hetzelfde, maar maak er een DataFrame van.</b>

# %% [markdown]
# <b>Maak de variabel leeftijd_geslacht aan, en selecteer de kolommen leeftijd en geslacht. Zorg ervoor dat de output een dataframe is.</b>

# %% [markdown]
# <b>Je kunt uiteraard ook specifieke rijen oproepen. Maak een variabel vrouwen, de output is een dataframe met alle rijen met de data die over vrouwen gaan.</b>

# %% [markdown]
# <b>Hoe zou je ervoor zorgen dat alleen maar rijen waarvan de mensen jonger dan 35 zijn geselecteerd worden? Zet de output in de variabel jonger.</b>

# %% [markdown]
# <b>En wat als je alleen maar mannen wilt die jonger dan 30 zijn? Noem de variabel jonger_mannen.</b>

# %% [markdown]
# <b> Zoek de functie op waarmee je de rijen selecteert waarin Geslacht niet leeg is. Stop het resultaat in de variabel geslacht_bekend. </b>

# %% [markdown]
# # Loc en iloc

# %% [markdown]
# De syntax voor loc en iloc is:
# -  loc[rij_naam, kolom_naam]
# -  iloc[rij_positie, kolom_positie]

# %% [markdown]
# <b>Probeer het even zelf: kan jij de type auto van Ali selecteren? Probeer het met loc en met iloc. Let op: vergeet niet dat je in python bij 0 begint met tellen!</b>

# %% [markdown]
# <b>Soms wil je alle rijen of alle kolommen selecteren. Dit kun je doen door ":" te gebruiken in plaats van de naam of positie. Selecteer alle rijen voor Type auto (met loc of iloc), en dan alle kolommen voor Max. </b>

# %% [markdown]
# <b>Je kunt ook meerdere specifieke rijen of kolommen selecteren. Dit doe je door een lijst aan namen of posities te gebruiken in plaats van maar eentje. Selecteer de rijen voor Max en Zelal. </b>

# %% [markdown]
# <b> Slice de dataframe met loc zodat je de kolommen van leeftijd tot en met type auto krijgt voor Max en Zelal.

# %% [markdown]
# <b> Slice de dataframe met loc zodat je de kolommen Leeftijd en Geslacht hebt voor iedereen van Peter tot en met Zelal.</b>

# %% [markdown]
# <b> Een extra functie bij slicen die af en toe handig kan zijn is het toevoegen van een stap. Een stap is een soort extra selectie conditie. Kijk naar wat er hieronder gebeurt.</b>

# %% [markdown]
# <b> Slice de dataframe met loc zodat je de leeftijd van alle vrouwen selecteert.</b>

# %% [markdown]
# <b> Slice de dataframe zodat je de leeftijd ziet van alle vrouwen die een Ford hebben en de prijs daarvan.</b>

# %% [markdown]
# <b> Probeer met loc de cel waar er Peugot staat te vervangen met Peugeot. Let op: vergeet niet om eerst een kopie te maken van de dataframe omdat je data gaat aanpassen.

# %% [markdown]
# <b> Vervang alle fouten in de dataframe met logischere waarden. </b>

# %% [markdown]
# <b> Vervang met loc alle data waarvan de leeftijd boven de 30 is met "oud".</b>

# %% [markdown]
# <b> Maak een nieuwe kolom aan die jong/oud heet. Voor alle mensen die tot en met 30 zijn vul je "jong" in, bij de rest vul je "oud" in.</b>

# %% [markdown]
# <b>Soms wil je een lege kolom toevoegen. Die kan je daarna vullen met de gegevens die je wilt. Hiervoor gebruik je de insert() functie. Deze heeft de volgende parameters:loc, column, value, allow_duplicates= True/False). Bij loc geef je aan waar je wilt dat de kolom toegevoegd wordt (vergeet niet vanaf 0 te tellen!). Column is de naam van de kolom, value de waarde. Voeg een lege kolom toe rechts van Leeftijd. </b>

# %% [markdown]
# <b>Wat ook heel nuttig is, is om door alle rijen te kunnen gaan om bepaalde gegevens te selecteren. Dit doe je met een for loop, en de iterrows() functie. Zoek informatie op over deze functie. Vervolgens schrijf je een stukje code die door alle rijen gaat en kijkt of iemand tot en met 30 is of ouder. For iedere persoon boven de 30 print je "NAAM is LEEFTIJD. Dat is oud.".</b>

# %% [markdown]
# <b>Het laaste wat we gaan doen is de dataframe omzetten naar een csv-bestand. Hiervoor gebruik je de functie DataFrame.to_csv(). Zoek deze functie op, en probeer de dataframe df op te slaan als csv-bestand.</b>

# %% [markdown]
# <b> Vervolgens ga je het bestand weer inlezen om er een pandas dataframe van te maken. Hiervoor gebruik je de functie read_csv(). Zoek deze functie op, en lees het bestand in om er een nieuwe dataframe van te maken.</b>

# %% [markdown]
# In deze oefeningen heb je geleerd:
#    -  Hoe je bepaalde rijen en kolommen (conditioneel) selecteert
#    -  Hoe je waarden kunt aanpassen
#    -  Hoe je specifieke onderdelen van een dataframe kunt selecteren
#    -  Hoe je door alle rijen van een dataframe kunt loopen om vervolgens een actie uit te voeren
#    -  Hoe je een dataframe omzet naar een csv-bestand
#    -  Hoe je een csv-bestand inleest als dataframe.
