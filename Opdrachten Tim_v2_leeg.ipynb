# %% [markdown]
# # Data-analyse en data-opschoning met een groot bestand

# %% [markdown]
# ## Introductie
#
# Vandaag gaan we met een grote dataset werken die je misschien ook wel zou tegenkomen in gemeenteland. Het importeren van een dataset via pandas gaat op deze manier:
#
# `df = pd.read_csv('hier de bestandsnaam', delimiter='hier het scheidingsteken')`
#
# Importeer het csv-bestand 'Databestand1' in Python en bekijk de dataset. Let op dat je importeert met het goede scheidingsteken!

# %% [markdown]
# ## Dataframe-check
#
# Je hebt nu de dataframe geÃ¯mporteerd, gefeliciteerd! Het is een grote kans dat als je een ruwe data-set krijgt van een organisatie, dat het er niet netjes uit ziet. Het eerste wat we ook doen, is checken wat voor dataframe het is. Bestudeer de data-set en beantwoord de volgende vragen:
#
# ### Aantal variabelen en regels
# - Vraag 1: Hoeveel variabelen zijn er?
# - Vraag 2: Hoeveel rijen zijn er?

# %% [markdown]
# ### Vraag 3. Lege cellen.
#   1. Hoeveel lege cellen zijn er? In totaal (1) en per variabele (2)?
#   2. Welk percentage van de cellen is leeg? In totaal (1) en per variabele (2)?
#   3. Is dit aanvaardbaar?
#
# Als je de lege cellen per variabele laat zien, zorg dan dat ze op volgorde van groot naar klein staan.

# %% [markdown]
# #### 3.1 Hoeveel lege cellen zijn er? In totaal (1) en per variabele (2)?
# 3.1.1 Totaal lege cellen

# %% [markdown]
# 3.1.2 Lege cellen per variabele

# %% [markdown]
# #### 3.2 Welk percentage van de cellen is leeg? In totaal (1) en per variabele (2)?
# 3.2.1 Totaal percentage lege cellen

# %% [markdown]
# 3.2.2 Percentage lege cellen per variabele

# %% [markdown]
# ### Vraag 4: Heeft elke variabele een titel? Wat valt je op aan de titels van de variabelen?

# %% [markdown]
# #### Vraag 5: hoeveel unieke cliÃ«ntnummers zitten er in de dataset?

# %% [markdown]
# Nadat je deze vragen hebt beantwoord, maak een slice van de dataset: vraag de eerste 50 regels op van de dataframe en stop deze in de variabele dfhead.
#
# - Vraag 6: Met wat voor data heb ik te maken?
# - Vraag 7: Zitten er eventueel dubbelingen in? Hoe zou je exact dubbele rijen verwijderen (en doe dat)?
# - Vraag 8: Hoeveel jaren zorg in totaal hebben deze cliÃ«nten gehad?

# %% [markdown]
# #### Antwoord vraag 5 t/m 7:
#
# Dit ziet er uit als zorgindicaties van jeudgdigen. Je ziet verschillende producten staan, en hoeveel de indicaties kosten. Je ziet ook dat er verschillende jeugdigden zijn met meerdere indicaties. Ook zijn er een aantal dubbelingen. Op deze manier kun je exact dubbele rijen verwijderen:

# %% [markdown]
# Op deze manier kun je een som maken van Ã©Ã©n variabele:

# %% [markdown]
# #### Nieuwe kolom maken
#
# Nu heb je ongeveer een beeld van hoe je met Python vlug maar goed naar de data kan kijken. Nu willen wij een nieuwe kolom aanmaken, namelijk het gemiddelde aantal euro's zorg per dag. We gaan hierbij weer werken met de originele dataset `df`.
#
# We gebruiken hiervoor deze twee kolommen in de dataset `df`: `Aantaldagenzorg` en `Totalekosten`. Maak een nieuwe kolom aan waarbij je het aantal kosten per dag berekent. Haal eerst alle rijen weg met een totaal aantal kosten van < 100 euro.
#
# Check daarnaast of er rijen zijn waarbij de einddatum vÃ³Ã³r de begindatum ligt. Hoe zou je ervoor kunnen zorgen dat deze rijen worden verwijderd?

# %% [markdown]
# #### Data opschonen
# Je besluit je data wat op te schonen. Je maakt een subset van `df` genaamd `df2` waarin je deze kolommen graag wil houden: Clientnummer, Leeftijd, Postcode, Aantaldagenzorg, Productcode, Totalekosten, Kostenperdag. Dit kan je met dit command doen. Waarom staan er twee brackets?
#
# `df2 = df[['kolom 1','kolom 2']]`
#
# Daarna wil je de kolom `Kostenperdag` graag afronden in centen. Verwijder daarna alle rijen met NAs erin.

# %% [markdown]
# #### Grafieken en tabellen
#
# Een mooie manier om je data te laten zien, is door middel van grafieken en tabellen. Je kunt met python, net zoals met Excel, ook een draaitabel maken (een pivot table). Probeer een mooie draaitabel te maken (hint: kijk naar het plaatje hieronder). Vergeet ook niet een nieuwe dataframe te maken!
#
# <img src="https://pbpython.com/images/pivot-table-datasheet.png" alt="drawing" width="600"/>

# %% [markdown]
# Zijn er andere manieren om de dataframe te groeperen op leeftijd?

# %% [markdown]
# Maak van df3 een mooie plot:

# %% [markdown]
# * Crosstabs, draaitabellen
